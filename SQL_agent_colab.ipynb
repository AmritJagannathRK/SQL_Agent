# %%
# !rm -rf /content/*
# !wget https://raw.githubusercontent.com/AmritJagannathRK/SQL_Agent/refs/heads/main/app.py
# !wget https://raw.githubusercontent.com/AmritJagannathRK/SQL_Agent/refs/heads/main/employee_data.csv
# Out:
# --2025-02-24 09:53:57--  https://raw.githubusercontent.com/AmritJagannathRK/SQL_Agent/refs/heads/main/app.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4546 (4.4K) [text/plain]
# Saving to: ‘app.py’
#
# app.py              100%[===================>]   4.44K  --.-KB/s    in 0s
#
# 2025-02-24 09:53:57 (59.4 MB/s) - ‘app.py’ saved [4546/4546]

# %%
! pip install streamlit -q
# !pip install -q -U bitsandbytes
# !pip install -q transformers torch huggingface_hub accelerate

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.139.144.42

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.2:8501
#   External URL: http://34.139.144.42:8501
#
# ⠸⠼⠴⠦⠧your url is: https://large-melons-roll.loca.lt
# CSV data uploaded successfully!
# 2025-02-24 04:47:20.982374: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-24 04:47:21.006267: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-24 04:47:21.015150: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
